# %%
import matplotlib.pyplot as plt
import numpy as np
import json

from pathlib import Path

figpath = Path("/Users/yangjunjie/Downloads")

import matplotlib
import matplotlib.pyplot as plt
# use latex globally
matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['font.family'] = 'serif'

data = None
with open('../data/nio-afm.json', 'r') as f:
    data = json.load(f)

# data_old = None
# with open('../data/diamond-old.json', 'r') as f:
#     data_old = json.load(f)

# # combine data from old and new
# data = {**data_old, **data}

basis = []
nkpt = []
kecut = []
method = []
for d in data:
    # print(d, data[d])
    basis.append(data[d].get('basis', ''))
    nkpt.append(int(data[d].get('nkpt', 0)))
    ke_cutoff = data[d].get('ke_cutoff', 0)
    if ke_cutoff != 'None':
        kecut.append(float(ke_cutoff))
    method.append(data[d].get('method', ''))
# for d in data_old:
#     basis.append(data_old[d].get('basis', ''))
#     nkpt.append(int(data_old[d].get('nkpt', 0)))
#     ke_cutoff = data_old[d].get('ke_cutoff', 0)
#     if ke_cutoff != 'None':
#         kecut.append(float(ke_cutoff))
#     method.append(data_old[d].get('method', ''))
basis = list(set(basis))
nkpt = list(set(nkpt))
kecut = list(set(kecut))
method = list(set(method))

# print(basis)

nkpt.sort()
kecut.sort()
print(method)

color = {'FFTISDF': 'b', 'GDF': 'r', 'FFTDF': 'g'}

print(basis, nkpt, kecut, method)
# Out:
# ['fftdf', 'fftisdf-10', 'gdf', 'fftisdf-20', 'fftisdf-40']
# ['gth-dzvp-molopt-sr'] [2, 4, 8, 12, 18, 27, 36, 48, 64] [0.0, 50.0, 200.0, 400.0] ['fftdf', 'fftisdf-10', 'gdf', 'fftisdf-20', 'fftisdf-40']

# %%
def plot_time(method, nkpt, basis, kecut):
    fig1, ax1 = plt.subplots(1, 1, figsize=(6, 3.8))
    fig2, ax2 = plt.subplots(1, 1, figsize=(6, 3.8))
    fig3, ax3 = plt.subplots(1, 1, figsize=(6, 3.8))

    figs = [fig1, fig2, fig3]
    axs = [ax1, ax2, ax3]

    # fig, axs = plt.subplots(3, 1, figsize=(6, 5), sharex=True, sharey=True)
    # for ikey, key in enumerate(['time_build_df', 'time_get_vk', 'time_get_eri']):
    y_label = ['Build Time (s)', 'Exchange Time (s)', 'ERI Time (s)']
    for ikey, key in enumerate(['time_build_df', 'time_get_vk', 'time_get_eri']):
        ax = axs[ikey]
        fig = figs[ikey]
        
        for m in method:
            x = []
            y = []
            for n in nkpt:
                for p, d in data.items():
                    is_in_list = False
                    d_b = d.get('basis', '')
                    d_k = d.get('ke_cutoff', 0.0)
                    d_k = float(d_k) if d_k != 'None' else 0.0
                    d_n = int(d.get('nkpt', 0))
                    d_m = d.get('method', '')

                    is_in_list = (basis in d_b)

                    if m != 'gdf':
                        is_in_list = is_in_list and (d_k == kecut)
                    is_in_list = is_in_list and (d_n == n)
                    is_in_list = is_in_list and (d_m == m)
                    t = d.get(key, np.nan)

                    if "fftisdf" in m and "get_eri" in key:
                        t = t / 8

                    if is_in_list:
                        x.append(n)
                        y.append(t)


            label = m.split('-')[0].upper()
            x = np.log2(x)
            ax.semilogy(x, y, c=color[label], label=label, marker='>', base=2, linestyle='--')
            ax.set_xlim(x.min(), x.max())
            ax.set_ylabel(y_label[ikey], fontsize=14)
            ax.grid(
                which='major',
                axis='both',
                linestyle='--',
                linewidth=0.5,
                color='gray'
            )
            ax.set_ylim((3) ** (-2), 2**18)
            ax.set_yticks([2 ** -2, 2 ** 2, 2 ** 6, 2 ** 10, 2 ** 14, 2 ** 18])
            ax.set_yticklabels([r'$2^{-2}$', r'$2^2$', r'$2^6$', r'$2^{10}$', r'$2^{14}$', r'$2^{18}$'])

        # ax = axs[-1]
        ax.set_xlabel(r'$N_{\mathbf{k}}$', fontsize=14)

        xx = range(1, 6)
        ax.set_xlim(2, 6)
        ax.set_xticks(xx)
        ax.set_xticklabels([r'$%d$' % (2 ** i) for i in xx])
        ax.legend(loc='upper left', bbox_to_anchor=(0, 1.20), ncol=3, fontsize=12, frameon=False)

        fig.tight_layout()
        fig.show(ikey)
    return figs, axs

# %%
nkpt = nkpt
kecut = 200.0
basis = 'dzvp' # -molopt-sr'
method = ['fftdf', 'gdf', 'fftisdf-10']
figs, axs = plot_time(method, nkpt, basis, kecut)

for ix, (fig, ax) in enumerate(zip(figs, axs)):
    # ax.text(
    #     0.35, 0.85, r'DZVP Diamond $c = 20$, $E_{\mathrm{cut}}$ = %6.2f' % (basis.upper(), kecut), 
    #     fontsize=13,
    #     ha='center',
    #     va='center',  transform=ax.transAxes
    # )

    ax.text(0.1, 0.9, r'NiO, DZVP' % (nkpt), ha='left', va='center', transform=ax.transAxes, fontsize=16)
    ax.text(0.1, 0.75, r'$c$ = %d, $E_{\mathrm{cut}}=%6.2f$' % (20, 200), ha='left', va='center', transform=ax.transAxes, fontsize=16)

    fig.savefig(figpath / ('time-nio-afm-dzvp-%d.png' % ix), dpi=300)
# Out:
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_37169/193534321.py:47: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(x.min(), x.max())
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_37169/193534321.py:47: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(x.min(), x.max())
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_37169/193534321.py:70: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show(ikey)
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_37169/193534321.py:47: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(x.min(), x.max())
# ...

# %%
nkpt = nkpt
kecut = 50.0
basis = 'gth-dzvp' # -molopt-sr'
method = ['fftdf', 'gdf', 'fftisdf-10']
figs, axs = plot_time(method, nkpt, basis, kecut)

for ix, (fig, ax) in enumerate(zip(figs, axs)):
    # ax.text(
    #     0.35, 0.85, r'DZVP Diamond $c = 20$, $E_{\mathrm{cut}}$ = %6.2f' % (basis.upper(), kecut), 
    #     fontsize=13,
    #     ha='center',
    #     va='center',  transform=ax.transAxes
    # )

    ax.text(0.1, 0.9, r'Diamond, DZVP' % (nkpt), ha='left', va='center', transform=ax.transAxes, fontsize=16)
    ax.text(0.1, 0.75, r'$c$ = %d, $E_{\mathrm{cut}}=%6.2f$' % (20, 100), ha='left', va='center', transform=ax.transAxes, fontsize=16)

    fig.savefig(figpath / ('time-diamond-dzvp-%d.png' % ix), dpi=300)
# Out:
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_37169/193534321.py:70: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show(ikey)
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_37169/193534321.py:70: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show(ikey)

# %%
nkpt = nkpt
kecut = 100.0
basis = 'gth-dzvp'
method = ['fftdf', 'gdf', 'fftisdf-10']
plot_time(method, nkpt, basis, kecut)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[158], line 5
#       3 basis = 'gth-dzvp'
#       4 method = ['fftdf', 'gdf', 'fftisdf-10']
# ----> 5 plot_time(method, nkpt, basis, kecut)
#
# Cell In[155], line 47, in plot_time(method, nkpt, basis, kecut)
#      45 x = np.log2(x)
#      46 ax.semilogy(x, y, c=color[label], label=label, marker='>', base=2, linestyle='--')
# ---> 47 ax.set_xlim(x.min(), x.max())
#      48 ax.set_ylabel(y_label[ikey], fontsize=14)
#      49 ax.grid(
#      50     which='major',
#      51     axis='both',
#    (...)
#      54     color='gray'
#      55 )
#
# File ~/anaconda3/lib/python3.12/site-packages/numpy/core/_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ...

# %%
nkpt = nkpt
kecut = 400.0
basis = 'gth-dzvp'
method = ['fftdf', 'gdf', 'fftisdf-20']
plot_time(method, nkpt, basis, kecut)
# Out:
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:41: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_xlim(x.min(), x.max())
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:40: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.semilogy(x, y, c=color[label], label=label, marker='>', base=2, linestyle='--')
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:60: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show(ikey)
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:60: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show(ikey)
# ([<Figure size 600x380 with 1 Axes>,
#   <Figure size 600x380 with 1 Axes>,
#   <Figure size 600x380 with 1 Axes>],
#  [<Axes: xlabel='$N_{\\mathbf{k}}$', ylabel='Build Time (s)'>,
# ...

# %%
nkpt = nkpt
kecut = 400.0
basis = 'gth-szv'
method = ['fftdf', 'gdf', 'fftisdf-40']
plot_time(method, nkpt, basis, kecut)
# Out:
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:41: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_xlim(x.min(), x.max())
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:40: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.semilogy(x, y, c=color[label], label=label, marker='>', base=2, linestyle='--')
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:60: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show(ikey)
# /var/folders/sm/7t_ndz1j5n5dlj8m6tnm2h480000gn/T/ipykernel_19436/4021227273.py:60: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show(ikey)
# ([<Figure size 600x380 with 1 Axes>,
#   <Figure size 600x380 with 1 Axes>,
#   <Figure size 600x380 with 1 Axes>],
#  [<Axes: xlabel='$N_{\\mathbf{k}}$', ylabel='Build Time (s)'>,
# ...
